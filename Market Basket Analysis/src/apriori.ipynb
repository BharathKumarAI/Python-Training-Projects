# %% [markdown]
# # Aprirori Algorithm

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

## Association Rule Learning (ARL)
import apyori as ap


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/market_basket.csv")
df.head()
# Out:
#    Unnamed: 0                               items  \
# 0           1      MEDIUM CERAMIC TOP STORAGE JAR
# 1           2     BLACK CANDELABRA T-LIGHT HOLDER
# 2           3  PINK NEW BAROQUECANDLESTICK CANDLE
# 3           4   AIRLINE BAG VINTAGE JET SET WHITE
# 4           5                  RABBIT NIGHT LIGHT
#
#                             Unnamed: 2                         Unnamed: 3  \
# 0                                  NaN                                NaN
# 1    AIRLINE BAG VINTAGE JET SET BROWN  COLOUR GLASS. STAR T-LIGHT HOLDER
# 2  BLUE NEW BAROQUE CANDLESTICK CANDLE    BLACK CANDELABRA T-LIGHT HOLDER
# 3      AIRLINE BAG VINTAGE JET SET RED       AIRLINE BAG VINTAGE TOKYO 78
# 4                 REGENCY TEA STRAINER            REGENCY TEA PLATE GREEN
#
#                           Unnamed: 4                           Unnamed: 5  \
# 0                                NaN                                  NaN
# 1             MINI PAINT SET VINTAGE  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN
# 2             WOODLAND CHARLOTTE BAG    AIRLINE BAG VINTAGE JET SET BROWN
# 3  AIRLINE BAG VINTAGE JET SET BROWN                  RED RETROSPOT PURSE
# 4             REGENCY TEA PLATE PINK              REGENCY TEA PLATE ROSES
#
#                            Unnamed: 6                           Unnamed: 7  \
# 0                                 NaN                                  NaN
# 1  PINK DRAWER KNOB ACRYLIC EDWARDIAN  GREEN DRAWER KNOB ACRYLIC EDWARDIAN
# 2   AIRLINE BAG VINTAGE JET SET WHITE                 SANDWICH BATH SPONGE
# 3          ICE CREAM SUNDAE LIP GLOSS    VINTAGE HEADS AND TAILS CARD GAME
# 4                REGENCY TEAPOT ROSES             REGENCY SUGAR BOWL GREEN
#
#                           Unnamed: 8                           Unnamed: 9  \
# 0                                NaN                                  NaN
# 1  RED DRAWER KNOB ACRYLIC EDWARDIAN  PURPLE DRAWERKNOB ACRYLIC EDWARDIAN
# 2     ALARM CLOCK BAKELIKE CHOCOLATE           ALARM CLOCK BAKELIKE GREEN
# 3                   HOLIDAY FUN LUDO             TREASURE ISLAND BOOK BOX
# 4              REGENCY MILK JUG PINK         AIRLINE BAG VINTAGE TOKYO 78
#
#    ... Unnamed: 541 Unnamed: 542 Unnamed: 543 Unnamed: 544 Unnamed: 545  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...          NaN          NaN          NaN          NaN          NaN
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 546 Unnamed: 547 Unnamed: 548 Unnamed: 549 Unnamed: 550
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 551 columns]
